# %% [markdown]
# # AVN GUI

# %% [markdown]
# *Coming Soon...*
#
# We are hard at work on the AVN GUI and hope to release a beta version before the end of Spring 2024. In the meantime, you can use the AVN python package to calculate acoustic, timing and syntax features of song and measure song similarity.

# %%
from IPython.display import Image
Image(filename = 'under construction.png', embed = True, width=300)
